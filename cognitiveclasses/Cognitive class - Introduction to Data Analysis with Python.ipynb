# %%
import pandas as pd
import numpy as np

# %%
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df = pd.read_csv(url,header=None)
#df.head(10)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
df.columns=headers
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe(include="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# # Dealing with missing value

# %%
df1=df.replace('?',np.NaN)

df1.dropna(subset=["price"],axis=0,inplace=True)

# %%
df1["price"].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '32250', '35550', '36000',
#        '5195', '6095', '6795', '6695', '7395', '10945', '11845', '13645',
#        '15645', '8495', '10595', '10245', '10795', '11245', '18280',
#        '18344', '25552', '28248', '28176', '31600', '34184', '35056',
#        '40960', '45400', '16503', '5389', '6189', '6669', '7689', '9959',
#        '8499', '12629', '14869', '14489', '6989', '8189', '9279', '5499',
#        '7099', '6649', '6849', '7349', '7299', '7799', '7499', '7999',
#        '8249', '8949', '9549', '13499', '14399', '17199', '19699',
# ...

# %%
#df1=pd.to_numeric(df1["normalized-losses"])
df1["normalized-losses"]=df1["normalized-losses"].astype('float')
df1["price"] = df1["price"].astype('int')
df1.info()
#mean_normalized_losses = df1["normalized-losses"].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
mean_normalized_losses = df1["normalized-losses"].mean()
mean_normalized_losses
# Out:
# 122.0

# %%
df1["normalized-losses"]=df1["normalized-losses"].replace(np.nan,mean_normalized_losses)

# %%
df1.head(10)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3              122.0  alfa-romero       gas        std
# 1           3              122.0  alfa-romero       gas        std
# 2           1              122.0  alfa-romero       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              164.0         audi       gas        std
# 5           2              122.0         audi       gas        std
# 6           1              158.0         audi       gas        std
# 7           1              122.0         audi       gas        std
# 8           1              158.0         audi       gas      turbo
# 10          2              192.0          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# ...

# %%
#conver city-mpg to city-L/100KM 
df1["city-mpg"]=235/df1["city-mpg"]
df1.rename(columns={"city-mpg":"city-L/100km"},inplace=True)

# %%
df1.head(10)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3              122.0  alfa-romero       gas        std
# 1           3              122.0  alfa-romero       gas        std
# 2           1              122.0  alfa-romero       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              164.0         audi       gas        std
# 5           2              122.0         audi       gas        std
# 6           1              158.0         audi       gas        std
# 7           1              122.0         audi       gas        std
# 8           1              158.0         audi       gas      turbo
# 10          2              192.0          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# ...

# %%
df1["price"]=df1["price"].astype("int")
df1.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-L/100km         float64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
#normalize length 
#df1["length"]=df1["length"]/df1["length"].max()

# %%
df1["length"].head(10)
# Out:
# 0     168.8
# 1     168.8
# 2     171.2
# 3     176.6
# 4     176.6
# 5     177.3
# 6     192.7
# 7     192.7
# 8     192.7
# 10    176.8
# Name: length, dtype: float64

# %%
#implement bins for price columns to distribute data 
bins = np.linspace(min(df1["price"]),max(df1["price"]),4)
bins
group_names=["low","Medium","High"]
df1["price-binned"]=pd.cut(df1["price"],bins,labels=group_names,include_lowest=True)
df1.hist(by="price-binned",column="price")
# Out:
# array([[<AxesSubplot:title={'center':'low'}>,
#         <AxesSubplot:title={'center':'Medium'}>],
#        [<AxesSubplot:title={'center':'High'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df1["price-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("price")
plt.pyplot.ylabel("count")
plt.pyplot.title("price bins")
# Out:
# Text(0.5, 1.0, 'price bins')

# %%
#convert catagorical variable into int type variable to be feed into models lie fuel column 
fuel_type=pd.get_dummies(df1["fuel-type"],drop_first=True)
fuel_type

dummy_variable_1 = pd.get_dummies(df1["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
df1 = pd.concat([df1, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df1.drop("fuel-type", axis = 1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       199 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %% [markdown]
# # EDA - Descriptive analysis

# %%
df1["drive-wheels"].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
# group by in pandas 
df_test  = df1[["drive-wheels","body-style","price"]]
df_test
df_grp = df_test.groupby(["drive-wheels","body-style"],as_index=False).mean()
df_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_pivot = df_grp.pivot(index="drive-wheels",columns="body-style")
df_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# # Analysis of Variance (ANOVA)

# %%
from scipy import stats
df_Anova = df1[["make","price"]]
grouped_anova = df_Anova.groupby(["make"])
anova_result_1 = stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("subaru")["price"])

anova_result_1
# Out:
# F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)

# %%
from scipy import stats
df_Anova = df1[["make","price"]]
grouped_anova = df_Anova.groupby(["make"])
anova_result_2 = stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("jaguar")["price"])

anova_result_2
# Out:
# F_onewayResult(statistic=400.925870564337, pvalue=1.0586193512077862e-11)

# %% [markdown]
# # Corelation between different variables

# %%
import seaborn as sns
sns.regplot(x="engine-size",y="price",data=df1)
plt.ylim(0,)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-279-07cfe49c3722> in <module>
#       1 import seaborn as sns
#       2 sns.regplot(x="engine-size",y="price",data=df1)
# ----> 3 plt.ylim(0,)
#
# AttributeError: module 'matplotlib' has no attribute 'ylim'

# %%
import matplotlib.pyplot as plt
plt.scatter(x="engine-size",y="price",data=df1)

# %%
sns.regplot(x="highway-mpg",y="price",data=df1)
plt.ylim(0,)
# Out:
# (0.0, 48172.31747099336)

# %%
sns.regplot(x="peak-rpm",y="price",data=df1)
plt.ylim(0,)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-286-4cf4fe9ef90c> in <module>
# ----> 1 sns.regplot(x="peak-rpm",y="price",data=df1)
#       2 plt.ylim(0,)
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     833     scatter_kws["marker"] = marker
# ...

# %% [markdown]
# # Pearson correlation

# %%
df1['horsepower']=df1['horsepower'].astype('float')

df1['horsepower'].dropna()

pearson_coef, pvalue = stats.pearsonr(df1['horsepower'],df1['price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-307-5ae656e982df> in <module>
#       3 df1['horsepower'].dropna()
#       4
# ----> 5 pearson_coef, pvalue = stats.pearsonr(df1['horsepower'],df1['price'])
#
# /Applications/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3528     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3529     # [-5e210, 5e210, 3e200, -3e200]
# -> 3530     normxm = linalg.norm(xm)
#    3531     normym = linalg.norm(ym)
#    3532
#
# /Applications/anaconda3/lib/python3.8/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
#     140     # Differs from numpy only in non-finite handling and the use of blas.
#     141     if check_finite:
# --> 142         a = np.asarray_chkfinite(a)
#     143     else:
#     144         a = np.asarray(a)
#
# ...
