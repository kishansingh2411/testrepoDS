# %%
name="Kishan"
subscribers=70000

# %%
import pandas as pd
import numpy as np

# %%
print(name + " has " + str(subscribers) + " youtube scribers now !")
# Out:
# Kishan has 70000 youtube scribers now !

# %%
df = pd.read_csv("Data/titanic.csv")
df1 = df[df["Age"] > 30]
df1.reset_index(inplace = True,drop=True)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              5         0       3
# 3              7         0       1
# 4             12         1       1
# ..           ...       ...     ...
# 300          874         0       3
# 301          880         1       1
# 302          882         0       3
# 303          886         0       3
# 304          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                             Allen, Mr. William Henry    male  35.0      0
# 3                              McCarthy, Mr. Timothy J    male  54.0      0
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # sorting the data in Pandas

# %%
df.sort_values(by=["Ticket","Fare"],ascending=[True,False]).head(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 257          258         1       1
# 504          505         1       1
# 759          760         1       1
# 262          263         0       1
# 558          559         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 262                                  Taussig, Mr. Emil    male  52.0      1
# 558             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
#
#      Parch  Ticket   Fare Cabin Embarked miles_class
# 257      0  110152  86.50   B77        S  high class
# 504      0  110152  86.50   B79        S  high class
# 759      0  110152  86.50   B77        S  high class
# 262      1  110413  79.65   E67        S  high class
# ...

# %% [markdown]
# # conditional statement

# %%
df["miles_class"] = np.where(df["Fare"] > 50,"high class","low_class")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#multiple conditions 
df["miles_class"] = np.where(df["Fare"] > 60,"high class",np.where(df["Fare"] > 40 ,"Medium_class","low_class"))
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# # grouping in pandas

# %%
df_group = df.groupby("miles_class")["Fare"].agg("sum")
#df_group = df.groupby("miles_class")["Fare"].sum()
df_group
# Out:
# miles_class
# Medium_class     2803.0627
# high class      15259.7207
# low_class       10631.1659
# Name: Fare, dtype: float64

# %%
uber = pd.read_csv("data/Uber-dataset/uber-raw-data-apr14.csv")
uber.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
df.groupby(["Age","Sex"])["Fare"].agg("mean","sum").head(30)
# Out:
# Age    Sex
# 0.42   male        8.516700
# 0.67   male       14.500000
# 0.75   female     19.258300
# 0.83   male       23.875000
# 0.92   male      151.550000
# 1.00   female     13.437500
#        male       36.633340
# 2.00   female     43.245833
#        male       28.971875
# 3.00   female     31.327100
#        male       23.009375
# 4.00   female     22.828340
#        male       36.258320
# 5.00   female     22.717700
# 6.00   female     32.137500
#        male       12.475000
# 7.00   female     26.250000
#        male       34.406250
# 8.00   female     23.662500
#        male       32.937500
# 9.00   female     27.198950
#        male       28.678125
# 10.00  female     24.150000
#        male       27.900000
# 11.00  female     31.275000
#        male       61.895833
# 12.00  male       11.241700
# 13.00  female     13.364600
# 14.00  female     42.291675
#        male       43.293750
# Name: Fare, dtype: float64
